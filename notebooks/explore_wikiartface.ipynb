# %%
# !pip install pyarrow
# !pip install fastparquet
# Out:
# Requirement already satisfied: pyarrow in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (8.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from pyarrow) (1.26.4)
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: pandas>=1.5.0 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from fastparquet) (2.2.3)
# Requirement already satisfied: numpy in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from fastparquet) (1.26.4)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting fsspec (from fastparquet)
#   Using cached fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from fastparquet) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading fastparquet-2024.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading cramjam-2.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 4.0 MB/s eta 0:00:0000:0100:01
# Using cached fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Installing collected packages: fsspec, cramjam, fastparquet
# Successfully installed cramjam-2.9.1 fastparquet-2024.11.0 fsspec-2025.3.0

# %%
# !pip install huggingface_hub
# Out:
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from huggingface_hub)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from requests->huggingface_hub) (2025.1.31)
# Downloading huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Installing collected packages: filelock, huggingface_hub
# Successfully installed filelock-3.18.0 huggingface_hub-0.29.3

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.4.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Using cached pyarrow-19.0.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.11.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from datasets) (0.29.3)
# Requirement already satisfied: packaging in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from datasets) (6.0.2)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp->datasets)
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from aiohttp->datasets) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets)
#   Downloading propcache-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets)
#   Downloading yarl-1.18.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (69 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/chezruth/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.4.0-py3-none-any.whl (487 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading aiohttp-3.11.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 744.3 kB/s eta 0:00:00:0100:01
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Using cached pyarrow-19.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (42.1 MB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
# Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Downloading propcache-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (205 kB)
# Downloading yarl-1.18.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (319 kB)
# Installing collected packages: xxhash, pyarrow, propcache, multidict, fsspec, frozenlist, dill, async-timeout, aiohappyeyeballs, yarl, multiprocess, aiosignal, aiohttp, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 8.0.0
#     Uninstalling pyarrow-8.0.0:
#       Successfully uninstalled pyarrow-8.0.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.11.14 aiosignal-1.3.2 async-timeout-5.0.1 datasets-3.4.0 dill-0.3.8 frozenlist-1.5.0 fsspec-2024.12.0 multidict-6.1.0 multiprocess-0.70.16 propcache-0.3.0 pyarrow-19.0.1 xxhash-3.5.0 yarl-1.18.3

# %%
import pandas as pd

df = pd.read_parquet("../../delorean_art_data/test-00000-of-00001.parquet")

# %%
df.head()
# Out:
#                                                image  \
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
#
#                          id  \
# 0  58e65509edc2cc6138daef35
# 1  58e48065edc2c9737800c6f6
# 2  58e48064edc2c9737800c529
# 3  57728606edc2cb388002e9d5
# 4  57728600edc2cb388002e1c8
#
#                                                title  \
# 0                                    Female Portrait
# 1  Portrait of the Famous Ukrainian Artist Tatian...
# 2                                      Self Portrait
# 3                                Vater des Künstlers
# 4                      Portrait of the young de Bros
#
#                                                  url        artistUrl  \
# 0                               female-portrait-1912  adalbert-erdeli
# 1  portrait-of-the-famous-ukrainian-artist-tatian...  adalbert-erdeli
# 2                                      self-portrait  adalbert-erdeli
# 3                                vater-des-k-nstlers   adolf-dietrich
# 4                    bildnis-des-jungen-de-bros-1898     albert-anker
#
#         artistName                  artistId  completitionYear  \
# 0  Adalbert Erdeli  58e47c47edc2c97378e6a299            1912.0
# 1  Adalbert Erdeli  58e47c47edc2c97378e6a299               NaN
# 2  Adalbert Erdeli  58e47c47edc2c97378e6a299               NaN
# 3   Adolf Dietrich  57726dd4edc2cb3880b5152e               NaN
# 4   Albrecht Anker  57726dd4edc2cb3880b5151a            1898.0
#
#                                         dictionaries location  ... media  \
# 0  [57726b52edc2cb3880ad7828, 57726b4eedc2cb3880a...           ...    []
# 1  [57726b51edc2cb3880ad7600, 57726b4eedc2cb3880a...           ...    []
# 2  [57726b51edc2cb3880ad7600, 57726b4eedc2cb3880a...           ...    []
# 3  [57726b52edc2cb3880ad76d0, 57726b4eedc2cb3880a...           ...    []
# 4  [57726b52edc2cb3880ad7828, 57726b4eedc2cb3880a...           ...    []
#
#   sizeX sizeY diameter galleries                           tags  description  \
# 0   NaN   NaN      NaN        []  [Sketch, Forehead, Chin, Jaw]
# 1   NaN   NaN      NaN        []                [Picture frame]
# 2   NaN   NaN      NaN        []                [Picture frame]
# 3   NaN   NaN      NaN        []    [Forehead, Chin, Gentleman]
# 4   NaN   NaN      NaN        []        [Hair, Lady, Hairstyle]
#
#    width height                  group
# 0    430    600     post-impressionism
# 1    524    600     post-impressionism
# 2    508    600     post-impressionism
# 3    434    570  naive-art-primitivism
# 4    487    600                realism
#
# [5 rows x 24 columns]
