# %% [markdown]
# # Assess diversity of databases with Fairface

# %% [markdown]
# https://github.com/dchen236/FairFace?tab=readme-ov-file

# %%
res34_fair_align_multi_4_20190809.pt
res34_fair_align_multi_7_20190809.pt

# %% [markdown]
# # Test dossier painting single face

# %%
import torch
import os
import pandas as pd
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image
from IPython.display import display  # Pour afficher les résultats dans Jupyter

# 📌 Définition des catégories FairFace (FairFace contient 18 classes)
ethnicities = [
    "White", "Black", "Latino_Hispanic", "East Asian", "Southeast Asian", 
    "Indian", "Middle Eastern", "Other", "Child", "Teen", "Young Adult", 
    "Adult", "Senior", "Male", "Female", "Smiling", "Not Smiling", "Unknown"
]

# 📌 Charger le modèle FairFace avec la bonne architecture
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet34(pretrained=False)
model.fc = torch.nn.Linear(model.fc.in_features, 18)  # Adapter à 18 classes

# 📌 Chemin du fichier modèle (⚠️ Change ce chemin si besoin)
model_path = "../FairFace/res34_fair_align_multi_4_20190809.pt"

# Vérifier si le fichier modèle existe
if not os.path.exists(model_path):
    raise FileNotFoundError(f"⚠️ Le fichier modèle {model_path} est introuvable. Vérifie le chemin.")

# Charger les poids du modèle FairFace
model.load_state_dict(torch.load(model_path, map_location=device))
model.to(device)
model.eval()

print("✅ Modèle FairFace chargé avec succès !")

# 🔹 Transformation des images (prétraitement pour le modèle)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def predict_ethnicity(image_path):
    """ Prédiction de l'ethnicité d'un visage dans une image """
    try:
        image = Image.open(image_path).convert("RGB")
        image = transform(image).unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(image)
            prediction = torch.argmax(output, dim=1).item()

        return ethnicities[prediction]
    
    except Exception as e:
        print(f"⚠️ Erreur avec {image_path} : {e}")
        return "Unknown"

# 📌 Dossier contenant les images à analyser (⚠️ MODIFIER ICI)
image_folder = "../raw_data/painting_test_set"

# Vérifier si le dossier existe
if not os.path.exists(image_folder):
    raise FileNotFoundError(f"⚠️ Le dossier {image_folder} est introuvable. Vérifie le chemin.")

# 🔹 Stocker les résultats
results = []

# Parcourir les images du dossier
for img_file in os.listdir(image_folder):
    img_path = os.path.join(image_folder, img_file)

    # Vérifier si c'est bien une image
    if img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
        ethnicity = predict_ethnicity(img_path)
        results.append({"image": img_file, "ethnicity": ethnicity})
        print(f"✅ {img_file} → {ethnicity}")

# 🔹 Convertir en DataFrame et sauvegarder
df_results = pd.DataFrame(results)
df_results.to_csv("diversity_results.csv", index=False)

print("📊 Analyse terminée ! Résultats enregistrés dans diversity_results.csv")

# 🔹 Afficher les résultats dans Jupyter Notebook
display(df_results)
# Out:
# ✅ Modèle FairFace chargé avec succès !
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg → White
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg → Latino_Hispanic
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg → Senior
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg → Latino_Hispanic
# ✅ edouard-vuillard_self-portrait-1.jpg → Latino_Hispanic
# ✅ yiannis-tsaroychis_schizophrenic-1968.jpg → Latino_Hispanic
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_t-te-de-jeune-fille.jp
# ✅ anita-malfatti_a-estudante-russa-1915.jpg → East Asian
# ✅ ferdinand-hodler_youth-admired-by-women.jpg → East Asian
# ✅ jacob-jordaens_homage-to-pomona-1616.jpg → Black
# ✅ richard-whitney_allen-kenney.jpg → Black
# ✅ aristarkh-lentulov_self-portrait-1915.jpg → White
# ✅ basuki-abdullah_an-indonesian-beauty.jpg → East Asian
# ✅ amrita-sher-gil_three-girls-1935.jpg → White
# ✅ john-french-sloan_young-woman-in-black-and-white-mary-kerr-1902.jpg → Black
# ✅ boris-kustodiev_portrait-of-a-k-kashparova-1911.jpg → White
# ✅ basuki-abdullah_bocah.jpg → East Asian
# ✅ alexey-venetsianov_head-of-an-old-peasant.jpg → White
# ✅ anton-azbe_zamorka-black-girl-1895.jpg → Other
# ✅ ernst-ludwig-kirchner_reclining-female-nude.jpg → White
# ✅ alexey-venetsianov_girl-with-accordion.jpg → Latino_Hispanic
# ✅ jamie-wyeth_kalounna-in-frogtown-1986.jpg → Senior
# ✅ augustus-john_mrs-a-a-jack-1898.jpg → Black
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_l-escale-1913.jpg → East Asian
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg → East Asian
# ✅ camille-corot_algerian-woman.jpg → White
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg → White
# ✅ augustus-john_edwin-john-1927.jpg → Other
# ✅ jamie-wyeth_portrait-of-andrew-wyeth-1969.jpg → Black
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg → Other
# ✅ juan-gris_pierrot-with-guitar-1925.jpg → White
# ✅ martial-raysse_portrait-de-mme-raysse-1963.jpg → White
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg → White
# 📊 Analyse terminée ! Résultats enregistrés dans diversity_results.csv
#                                                 image        ethnicity
# 0   sandro-botticelli_the-temptation-of-christ-148...            White
# 1              keisai-eisen_kiyomizu-komachi-1838.jpg  Latino_Hispanic
# 2   andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927...           Senior
# 3   benozzo-gozzoli_scenes-with-st-ambrose-detail-...  Latino_Hispanic
# 4                edouard-vuillard_self-portrait-1.jpg  Latino_Hispanic
# ..                                                ...              ...
# 76      jamie-wyeth_portrait-of-andrew-wyeth-1969.jpg            Black
# 77  jacob-jordaens_as-the-old-sang-so-the-young-pi...            Other
# 78             juan-gris_pierrot-with-guitar-1925.jpg            White
# 79     martial-raysse_portrait-de-mme-raysse-1963.jpg            White
# 80         john-french-sloan_jeanne-dubinsky-1942.jpg            White
#
# [81 rows x 2 columns]

# %% [markdown]
# # Prise en compte multi-visages

# %%
import torch
import os
import pandas as pd
import cv2
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image
from IPython.display import display

# 📌 Définition des catégories FairFace
ethnicities = [
    "White", "Black", "Latino_Hispanic", "East Asian", "Southeast Asian", 
    "Indian", "Middle Eastern", "Other", "Child", "Teen", "Young Adult", 
    "Adult", "Senior", "Male", "Female", "Smiling", "Not Smiling", "Unknown"
]

# 📌 Charger le modèle FairFace
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet34(pretrained=False)
model.fc = torch.nn.Linear(model.fc.in_features, 18)  # Adapter à 18 classes

# 📌 Chemin du fichier modèle (⚠️ Change ce chemin si besoin)
model_path = "../FairFace/res34_fair_align_multi_7_20190809.pt"

# Vérifier si le fichier modèle existe
if not os.path.exists(model_path):
    raise FileNotFoundError(f"⚠️ Le fichier modèle {model_path} est introuvable. Vérifie le chemin.")

# Charger les poids du modèle FairFace
model.load_state_dict(torch.load(model_path, map_location=device))
model.to(device)
model.eval()

print("✅ Modèle FairFace chargé avec succès !")

# 🔹 Transformation des images (prétraitement pour le modèle)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 🔹 Charger un détecteur de visages avec OpenCV
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

def detect_faces(image_path):
    """ Détecte les visages dans une image et retourne une liste de visages recadrés """
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Détecter les visages
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Extraire chaque visage détecté
    face_crops = []
    for (x, y, w, h) in faces:
        face = image[y:y+h, x:x+w]
        face_crops.append(face)

    return face_crops

def predict_ethnicity(face_image):
    """ Prédiction de l'ethnicité d'un visage recadré """
    try:
        # Convertir l'image en PIL
        face_pil = Image.fromarray(cv2.cvtColor(face_image, cv2.COLOR_BGR2RGB))
        face_pil = transform(face_pil).unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(face_pil)
            prediction = torch.argmax(output, dim=1).item()

        return ethnicities[prediction]

    except Exception as e:
        print(f"⚠️ Erreur avec un visage : {e}")
        return "Unknown"

# 📌 Dossier contenant les images à analyser (⚠️ MODIFIER ICI)
image_folder = "../raw_data/painting_test_set"

# Vérifier si le dossier existe
if not os.path.exists(image_folder):
    raise FileNotFoundError(f"⚠️ Le dossier {image_folder} est introuvable. Vérifie le chemin.")

# 🔹 Stocker les résultats
results = []

# Parcourir les images du dossier
for img_file in os.listdir(image_folder):
    img_path = os.path.join(image_folder, img_file)

    # Vérifier si c'est bien une image
    if img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
        face_crops = detect_faces(img_path)
        
        if len(face_crops) == 0:
            print(f"⚠️ Aucun visage détecté dans {img_file}")
            results.append({"image": img_file, "face_id": "None", "ethnicity": "Unknown"})
        else:
            for i, face in enumerate(face_crops):
                ethnicity = predict_ethnicity(face)
                results.append({"image": img_file, "face_id": f"Face {i+1}", "ethnicity": ethnicity})
                print(f"✅ {img_file} - Face {i+1} → {ethnicity}")

# 🔹 Convertir en DataFrame et sauvegarder
df_results = pd.DataFrame(results)
df_results.to_csv("diversity_results.csv", index=False)

print("📊 Analyse terminée ! Résultats enregistrés dans diversity_results.csv")

# 🔹 Afficher les résultats dans Jupyter Notebook
display(df_results)
# Out:
# ✅ Modèle FairFace chargé avec succès !
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 1 → White
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 2 → Senior
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 3 → Middle Eastern
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 4 → Senior
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 5 → Senior
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 6 → Black
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 7 → Senior
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 1 → Middle Eastern
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 2 → White
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 3 → Middle Eastern
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 4 → Senior
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 5 → East Asian
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 1 → Middle Eastern
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 2 → Middle Eastern
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 3 → East Asian
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 4 → Senior
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 4 → White
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 5 → Middle Eastern
# ⚠️ Aucun visage détecté dans juan-gris_pierrot-with-guitar-1925.jpg
# ✅ martial-raysse_portrait-de-mme-raysse-1963.jpg - Face 1 → White
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 1 → Senior
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 2 → White
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 3 → Senior
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 4 → East Asian
# 📊 Analyse terminée ! Résultats enregistrés dans diversity_results.csv
#                                                  image face_id       ethnicity
# 0    sandro-botticelli_the-temptation-of-christ-148...  Face 1           White
# 1    sandro-botticelli_the-temptation-of-christ-148...  Face 2          Senior
# 2    sandro-botticelli_the-temptation-of-christ-148...  Face 3  Middle Eastern
# 3    sandro-botticelli_the-temptation-of-christ-148...  Face 4          Senior
# 4    sandro-botticelli_the-temptation-of-christ-148...  Face 5          Senior
# ..                                                 ...     ...             ...
# 232     martial-raysse_portrait-de-mme-raysse-1963.jpg  Face 1           White
# 233         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 1          Senior
# 234         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 2           White
# 235         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 3          Senior
# 236         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 4      East Asian
#
# [237 rows x 3 columns]

# %%
df_results["ethnicity"].value_counts()
# Out:
# ethnicity
# White              75
# Senior             64
# Middle Eastern     28
# Black              15
# Male               15
# East Asian         13
# Unknown            12
# Other               5
# Not Smiling         2
# Adult               2
# Young Adult         2
# Southeast Asian     1
# Latino_Hispanic     1
# Indian              1
# Female              1
# Name: count, dtype: int64

# %% [markdown]
# # Prise en compte multi-visages avec labels sur la photo

# %%
import torch
import os
import pandas as pd
import cv2
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image
import numpy as np
from IPython.display import display

# 📌 Définition des 18 catégories FairFace
ethnicities = [
    "White", "Black", "Latino_Hispanic", "East Asian", "Southeast Asian", 
    "Indian", "Middle Eastern", "Other", "Child", "Teen", "Young Adult", 
    "Adult", "Senior", "Male", "Female", "Smiling", "Not Smiling", "Unknown"
]

# 📌 Charger le modèle FairFace
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet34(pretrained=False)

# 📌 Garder la dernière couche d'origine avec 18 classes
model.fc = torch.nn.Linear(model.fc.in_features, 18)

# 📌 Chemin du fichier modèle (⚠️ Modifier ici si nécessaire)
model_path = "../FairFace/res34_fair_align_multi_4_20190809.pt"

if not os.path.exists(model_path):
    raise FileNotFoundError(f"⚠️ Le fichier modèle {model_path} est introuvable.")

# Charger les poids du modèle (pré-entraîné avec 18 classes)
model.load_state_dict(torch.load(model_path, map_location=device))
model.to(device)
model.eval()

print("✅ Modèle FairFace chargé avec succès avec 18 catégories !")

# 🔹 Transformation des images
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 🔹 Détecteur de visages OpenCV
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

def detect_faces(image_path):
    """ Détecte les visages et retourne une liste des coordonnées (x, y, w, h) """
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    return faces

def predict_ethnicity(face_image):
    """ Prédiction de l'ethnicité d'un visage """
    try:
        face_pil = Image.fromarray(cv2.cvtColor(face_image, cv2.COLOR_BGR2RGB))
        face_pil = transform(face_pil).unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(face_pil)
            prediction = torch.argmax(output, dim=1).item()

        return ethnicities[prediction]  # 📌 Associer l'indice à l'ethnicité correspondante
    except Exception as e:
        print(f"⚠️ Erreur avec un visage : {e}")
        return "Unknown"

# 📌 Dossier des images (⚠️ Modifier ici)
image_folder = "../raw_data/painting_test_set"
output_folder = "../processed_data/FairFace"
os.makedirs(output_folder, exist_ok=True)

if not os.path.exists(image_folder):
    raise FileNotFoundError(f"⚠️ Le dossier {image_folder} est introuvable.")

# 🔹 Stocker les résultats
results = []

# 🔹 Traitement des images
for img_file in os.listdir(image_folder):
    img_path = os.path.join(image_folder, img_file)

    if img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
        image = cv2.imread(img_path)
        faces = detect_faces(img_path)
        
        if len(faces) == 0:
            print(f"⚠️ Aucun visage détecté dans {img_file}")
            results.append({"image": img_file, "face_id": "None", "ethnicity": "Unknown", "x": None, "y": None, "w": None, "h": None})
        else:
            for i, (x, y, w, h) in enumerate(faces):
                face = image[y:y+h, x:x+w]
                ethnicity = predict_ethnicity(face)

                results.append({"image": img_file, "face_id": f"Face {i+1}", "ethnicity": ethnicity, "x": x, "y": y, "w": w, "h": h})
                print(f"✅ {img_file} - Face {i+1} → {ethnicity} (x={x}, y={y}, w={w}, h={h})")

                # 🖼 Annoter l'image
                cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
                cv2.putText(image, ethnicity, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

            # Sauvegarder l'image annotée
            annotated_path = os.path.join(output_folder, f"annotated_{img_file}")
            cv2.imwrite(annotated_path, image)

# 🔹 Convertir en DataFrame et sauvegarder
df_results = pd.DataFrame(results)
df_results.to_csv("face_identification_results.csv", index=False)

print("📊 Analyse terminée ! Résultats enregistrés dans face_identification_results.csv")

# 🔹 Afficher les résultats dans Jupyter Notebook
display(df_results)
# Out:
# /home/carozero/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/carozero/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ✅ Modèle FairFace chargé avec succès avec 18 catégories !
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 1 → White (x=123, y=494, w=60, h=60)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 2 → Black (x=847, y=756, w=69, h=69)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 3 → Black (x=1477, y=766, w=73, h=73)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 4 → White (x=1859, y=879, w=173, h=173)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 5 → White (x=1244, y=1151, w=49, h=49)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 6 → White (x=1355, y=1119, w=165, h=165)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 7 → White (x=292, y=1299, w=60, h=60)
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 1 → Latino_Hispanic (x=1156, y=681, w=50, h=50)
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 2 → White (x=430, y=607, w=73, h=73)
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 3 → East Asian (x=760, y=951, w=72, h=72)
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 4 → Latino_Hispanic (x=807, y=1070, w=74, h=74)
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 5 → White (x=1177, y=1627, w=40, h=40)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 1 → White (x=593, y=239, w=188, h=188)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 2 → East Asian (x=1171, y=270, w=218, h=218)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 3 → Latino_Hispanic (x=1345, y=210, w=494, h=494)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 4 → Latino_Hispanic (x=649, y=624, w=61, h=61)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 5 → White (x=36, y=623, w=133, h=133)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 6 → Senior (x=2296, y=675, w=102, h=102)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 7 → White (x=116, y=864, w=52, h=52)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 8 → White (x=127, y=916, w=59, h=59)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 9 → White (x=1383, y=1041, w=106, h=106)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 1 → Black (x=860, y=125, w=59, h=59)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 2 → Black (x=1016, y=363, w=67, h=67)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 3 → Senior (x=867, y=315, w=153, h=153)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 4 → Not Smiling (x=1077, y=312, w=167, h=167)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 5 → White (x=588, y=346, w=156, h=156)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 6 → Latino_Hispanic (x=214, y=443, w=227, h=227)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 7 → East Asian (x=540, y=566, w=66, h=66)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 8 → Latino_Hispanic (x=602, y=599, w=56, h=56)
# ✅ edouard-vuillard_self-portrait-1.jpg - Face 1 → White (x=333, y=300, w=725, h=725)
# ✅ yiannis-tsaroychis_schizophrenic-1968.jpg - Face 1 → Other (x=209, y=457, w=616, h=616)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_t-te-de-jeune-fille.jpg - Face 1 → Black (x=336, y=812, w=136, h=136)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_t-te-de-jeune-fille.jpg - Face 2 → Black (x=521, y=717, w=125, h=125)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_t-te-de-jeune-fille.jpg - Face 3 → Latino_Hispanic (x=262, y=1293, w=63, h=63)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_t-te-de-jeune-fille.jpg - Face 4 → White (x=930, y=1722, w=44, h=44)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_t-te-de-jeune-fille.jpg - Face 5 → White (x=454, y=1629, w=345, h=345)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_t-te-de-jeune-fille.jpg - Face 6 → White (x=958, y=1902, w=60, h=60)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_t-te-de-jeune-fille.jpg - Face 7 → Latino_Hispanic (x=952, y=1834, w=67, h=67)
# ✅ juan-gris_pierrot-1919.jpg - Face 1 → Latino_Hispanic (x=1221, y=812, w=92, h=92)
# ✅ keisai-eisen_fukagawa-hachiman-no-shin-fuji-from-the-series-twelve-views-of-modern-beauties-imay-bijin-j-ni.jpg - Face 1 → White (x=574, y=1422, w=71, h=71)
# ✅ keisai-eisen_fukagawa-hachiman-no-shin-fuji-from-the-series-twelve-views-of-modern-beauties-imay-bijin-j-ni.jpg - Face 2 → White (x=568, y=1484, w=82, h=82)
# ✅ boris-kustodiev_portrait-of-a-singer-i-v-ershov-1905.jpg - Face 1 → White (x=436, y=298, w=405, h=405)
# ✅ andy-warhol_muhammad-ali.jpg - Face 1 → Senior (x=278, y=394, w=662, h=662)
# ✅ andy-warhol_muhammad-ali.jpg - Face 2 → Latino_Hispanic (x=52, y=1038, w=209, h=209)
# ✅ akseli-gallen-kallela_le-depart-de-v-in-m-inen-1906.jpg - Face 1 → White (x=1131, y=252, w=52, h=52)
# ✅ akseli-gallen-kallela_le-depart-de-v-in-m-inen-1906.jpg - Face 2 → East Asian (x=437, y=202, w=104, h=104)
# ✅ akseli-gallen-kallela_le-depart-de-v-in-m-inen-1906.jpg - Face 3 → White (x=395, y=244, w=160, h=160)
# ✅ akseli-gallen-kallela_le-depart-de-v-in-m-inen-1906.jpg - Face 4 → Latino_Hispanic (x=1280, y=599, w=49, h=49)
# ✅ akseli-gallen-kallela_le-depart-de-v-in-m-inen-1906.jpg - Face 5 → White (x=313, y=495, w=57, h=57)
# ✅ akseli-gallen-kallela_le-depart-de-v-in-m-inen-1906.jpg - Face 6 → White (x=374, y=378, w=59, h=59)
# ✅ akseli-gallen-kallela_le-depart-de-v-in-m-inen-1906.jpg - Face 7 → Senior (x=942, y=612, w=62, h=62)
# ✅ akseli-gallen-kallela_le-depart-de-v-in-m-inen-1906.jpg - Face 8 → White (x=1111, y=717, w=81, h=81)
# ✅ akseli-gallen-kallela_le-depart-de-v-in-m-inen-1906.jpg - Face 9 → Black (x=340, y=1049, w=60, h=60)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_les-deux-amies-1925.jpg - Face 1 → White (x=795, y=523, w=380, h=380)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_les-deux-amies-1925.jpg - Face 2 → White (x=673, y=1022, w=97, h=97)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_head-of-a-girl.jpg - Face 1 → White (x=352, y=465, w=585, h=585)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_head-of-a-girl.jpg - Face 2 → East Asian (x=1049, y=1122, w=64, h=64)
# ✅ fernand-leger_the-woman-with-black-hair-1952.jpg - Face 1 → White (x=239, y=115, w=849, h=849)
# ⚠️ Aucun visage détecté dans marjorie-strider_smiling-blonde.jpg
# ✅ marc-chagall_an-angel-1956.jpg - Face 1 → White (x=594, y=468, w=595, h=595)
# ✅ paul-signac_the-portrait-of-maximilien-luce-1891.jpg - Face 1 → Latino_Hispanic (x=629, y=536, w=54, h=54)
# ✅ amrita-sher-gil_bride-s-toilet-1937.jpg - Face 1 → White (x=146, y=340, w=54, h=54)
# ✅ amrita-sher-gil_bride-s-toilet-1937.jpg - Face 2 → White (x=1402, y=345, w=59, h=59)
# ✅ amrita-sher-gil_bride-s-toilet-1937.jpg - Face 3 → White (x=1669, y=476, w=55, h=55)
# ✅ amrita-sher-gil_bride-s-toilet-1937.jpg - Face 4 → Black (x=24, y=500, w=122, h=122)
# ✅ anders-zorn_mrs-walter-bacon-1891.jpg - Face 1 → White (x=344, y=354, w=409, h=409)
# ✅ anders-zorn_mrs-walter-bacon-1891.jpg - Face 2 → Latino_Hispanic (x=250, y=1170, w=80, h=80)
# ✅ anders-zorn_mrs-walter-bacon-1891.jpg - Face 3 → Latino_Hispanic (x=34, y=1365, w=67, h=67)
# ✅ anders-zorn_mrs-walter-bacon-1891.jpg - Face 4 → Latino_Hispanic (x=778, y=1299, w=102, h=102)
# ✅ anders-zorn_mrs-walter-bacon-1891.jpg - Face 5 → White (x=998, y=1591, w=47, h=47)
# ✅ basuki-abdullah_gadis-manis.jpg - Face 1 → Black (x=230, y=286, w=551, h=551)
# ✅ utagawa-kuniyoshi_portrait-of-daruma.jpg - Face 1 → White (x=902, y=1193, w=68, h=68)
# ⚠️ Aucun visage détecté dans kazimir-malevich_study-for-portrait-of-a-peasant.jpg
# ✅ theo-van-rysselberghe_three-children-in-blue-1901.jpg - Face 1 → East Asian (x=1362, y=208, w=37, h=37)
# ✅ theo-van-rysselberghe_three-children-in-blue-1901.jpg - Face 2 → White (x=1172, y=246, w=147, h=147)
# ✅ theo-van-rysselberghe_three-children-in-blue-1901.jpg - Face 3 → White (x=345, y=295, w=133, h=133)
# ✅ theo-van-rysselberghe_three-children-in-blue-1901.jpg - Face 4 → Senior (x=1016, y=311, w=149, h=149)
# ✅ theo-van-rysselberghe_three-children-in-blue-1901.jpg - Face 5 → East Asian (x=380, y=883, w=73, h=73)
# ✅ utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen.jpg - Face 1 → Senior (x=678, y=362, w=68, h=68)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 1 → East Asian (x=1271, y=316, w=55, h=55)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 2 → Black (x=76, y=400, w=64, h=64)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 3 → White (x=181, y=378, w=71, h=71)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 4 → White (x=869, y=413, w=164, h=164)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 5 → White (x=1019, y=527, w=57, h=57)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 6 → White (x=666, y=566, w=67, h=67)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 7 → White (x=104, y=866, w=159, h=159)
# ✅ fernando-botero_pope-leo-x-after-raphael.jpg - Face 1 → White (x=362, y=446, w=491, h=491)
# ⚠️ Aucun visage détecté dans fernand-leger_head-constructor-1950.jpg
# ✅ albert-huie_the-counting-lesson-1938.jpg - Face 1 → East Asian (x=214, y=144, w=73, h=73)
# ✅ albert-huie_the-counting-lesson-1938.jpg - Face 2 → East Asian (x=568, y=361, w=483, h=483)
# ✅ albert-huie_the-counting-lesson-1938.jpg - Face 3 → White (x=804, y=1141, w=58, h=58)
# ✅ yayoi-kusama_watching-the-sea-1989.jpg - Face 1 → East Asian (x=274, y=101, w=59, h=59)
# ✅ yayoi-kusama_watching-the-sea-1989.jpg - Face 2 → East Asian (x=1191, y=81, w=58, h=58)
# ✅ yayoi-kusama_watching-the-sea-1989.jpg - Face 3 → Black (x=1149, y=124, w=57, h=57)
# ✅ yayoi-kusama_watching-the-sea-1989.jpg - Face 4 → East Asian (x=1078, y=755, w=60, h=60)
# ✅ augustus-john_the-two-jamaican-girls-1937.jpg - Face 1 → White (x=959, y=925, w=43, h=43)
# ✅ augustus-john_the-two-jamaican-girls-1937.jpg - Face 2 → White (x=182, y=799, w=93, h=93)
# ✅ augustus-john_the-two-jamaican-girls-1937.jpg - Face 3 → White (x=109, y=851, w=117, h=117)
# ✅ augustus-john_the-two-jamaican-girls-1937.jpg - Face 4 → White (x=1023, y=1262, w=62, h=62)
# ✅ augustus-john_the-two-jamaican-girls-1937.jpg - Face 5 → Black (x=763, y=1503, w=53, h=53)
# ✅ basuki-abdullah_cantik.jpg - Face 1 → Senior (x=506, y=241, w=475, h=475)
# ✅ andy-warhol_sylvester-stallone-1980.jpg - Face 1 → Male (x=384, y=434, w=663, h=663)
# ✅ andy-warhol_sylvester-stallone-1980.jpg - Face 2 → Latino_Hispanic (x=590, y=519, w=67, h=67)
# ⚠️ Aucun visage détecté dans ernst-ludwig-kirchner_great-lovers-mr-and-miss-hembus.jpg
# ✅ keisai-eisen_pipe-smokers-1835(1).jpg - Face 1 → East Asian (x=223, y=384, w=68, h=68)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 1 → White (x=397, y=213, w=84, h=84)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 2 → White (x=346, y=345, w=187, h=187)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 3 → East Asian (x=1197, y=609, w=36, h=36)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 4 → Black (x=327, y=908, w=56, h=56)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 5 → Latino_Hispanic (x=1618, y=988, w=74, h=74)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 6 → Senior (x=772, y=1085, w=72, h=72)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 7 → Latino_Hispanic (x=751, y=1013, w=64, h=64)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 8 → White (x=1358, y=1017, w=89, h=89)
# ✅ boris-kustodiev_portrait-of-a-n-protasova-1900.jpg - Face 1 → White (x=496, y=279, w=396, h=396)
# ✅ jacob-jordaens_study-of-the-head-of-apollo.jpg - Face 1 → White (x=381, y=197, w=444, h=444)
# ✅ jacob-jordaens_study-of-the-head-of-apollo.jpg - Face 2 → East Asian (x=867, y=583, w=114, h=114)
# ✅ eric-fischl_willie-and-liz.jpg - Face 1 → Black (x=1166, y=65, w=197, h=197)
# ✅ eric-fischl_willie-and-liz.jpg - Face 2 → Black (x=251, y=135, w=209, h=209)
# ✅ eric-fischl_willie-and-liz.jpg - Face 3 → Latino_Hispanic (x=1063, y=1199, w=83, h=83)
# ✅ gilles-aillaud_la-bataille-du-riz-1968.jpg - Face 1 → Latino_Hispanic (x=431, y=315, w=103, h=103)
# ✅ gilles-aillaud_la-bataille-du-riz-1968.jpg - Face 2 → Latino_Hispanic (x=710, y=816, w=70, h=70)
# ✅ martial-raysse_made-in-japan-la-grande-odalisque-1964.jpg - Face 1 → Latino_Hispanic (x=622, y=467, w=637, h=637)
# ✅ martial-raysse_made-in-japan-la-grande-odalisque-1964.jpg - Face 2 → Latino_Hispanic (x=298, y=530, w=259, h=259)
# ✅ alexey-venetsianov_girl-with-milk.jpg - Face 1 → White (x=186, y=462, w=617, h=617)
# ✅ alexey-venetsianov_girl-with-milk.jpg - Face 2 → White (x=359, y=1161, w=71, h=71)
# ✅ alexey-venetsianov_girl-with-milk.jpg - Face 3 → White (x=165, y=1094, w=127, h=127)
# ✅ alexey-venetsianov_girl-with-milk.jpg - Face 4 → White (x=538, y=1337, w=63, h=63)
# ✅ alexey-venetsianov_girl-with-milk.jpg - Face 5 → White (x=19, y=1521, w=81, h=81)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_pequena-fiandeira-napolitana-1877.jpg - Face 1 → Senior (x=450, y=249, w=191, h=191)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto_pequena-fiandeira-napolitana-1877.jpg - Face 2 → Latino_Hispanic (x=602, y=1889, w=59, h=59)
# ✅ anders-zorn_grandmother-1892.jpg - Face 1 → White (x=539, y=372, w=567, h=567)
# ✅ andy-warhol_tatum-o-neal-1987.jpg - Face 1 → White (x=332, y=476, w=613, h=613)
# ⚠️ Aucun visage détecté dans evelyne-axell_ice-cream-1964.jpg
# ✅ fernando-botero_miss-riviere-after-ingres.jpg - Face 1 → Senior (x=271, y=290, w=521, h=521)
# ✅ fernando-botero_miss-riviere-after-ingres.jpg - Face 2 → White (x=66, y=1720, w=107, h=107)
# ⚠️ Aucun visage détecté dans boris-kustodiev_portrait-of-y-e-kustodieva-1925.jpg
# ✅ albert-huie_self-portrait-1943.jpg - Face 1 → Black (x=163, y=257, w=1023, h=1023)
# ✅ albert-huie_self-portrait-1943.jpg - Face 2 → Latino_Hispanic (x=278, y=1265, w=78, h=78)
# ✅ albert-huie_self-portrait-1943.jpg - Face 3 → East Asian (x=283, y=1527, w=58, h=58)
# ✅ albert-huie_self-portrait-1943.jpg - Face 4 → Senior (x=1148, y=1551, w=104, h=104)
# ✅ jamie-wyeth_katie-on-southern-1998.jpg - Face 1 → White (x=797, y=257, w=217, h=217)
# ✅ sandro-botticelli_the-story-of-nastagio-degli-onesti-the-banquet-in-the-pine-forest-1483(1).jpg - Face 1 → White (x=179, y=352, w=58, h=58)
# ✅ sandro-botticelli_the-story-of-nastagio-degli-onesti-the-banquet-in-the-pine-forest-1483(1).jpg - Face 2 → White (x=1532, y=534, w=48, h=48)
# ✅ sandro-botticelli_the-story-of-nastagio-degli-onesti-the-banquet-in-the-pine-forest-1483(1).jpg - Face 3 → White (x=682, y=673, w=53, h=53)
# ✅ sandro-botticelli_the-story-of-nastagio-degli-onesti-the-banquet-in-the-pine-forest-1483(1).jpg - Face 4 → White (x=1020, y=692, w=80, h=80)
# ✅ sandro-botticelli_the-virgin-and-child-enthroned-1484(1).jpg - Face 1 → White (x=1078, y=325, w=111, h=111)
# ✅ sandro-botticelli_the-virgin-and-child-enthroned-1484(1).jpg - Face 2 → White (x=167, y=342, w=102, h=102)
# ✅ sandro-botticelli_the-virgin-and-child-enthroned-1484(1).jpg - Face 3 → White (x=662, y=217, w=85, h=85)
# ✅ sandro-botticelli_the-virgin-and-child-enthroned-1484(1).jpg - Face 4 → Latino_Hispanic (x=639, y=159, w=113, h=113)
# ✅ edouard-vuillard_self-portrait.jpg - Face 1 → Black (x=249, y=278, w=59, h=59)
# ✅ edouard-vuillard_self-portrait.jpg - Face 2 → Black (x=976, y=73, w=66, h=66)
# ✅ edouard-vuillard_self-portrait.jpg - Face 3 → Black (x=975, y=1309, w=60, h=60)
# ✅ richard-whitney_nancy.jpg - Face 1 → White (x=725, y=349, w=259, h=259)
# ✅ richard-whitney_nancy.jpg - Face 2 → White (x=136, y=498, w=82, h=82)
# ✅ richard-whitney_nancy.jpg - Face 3 → White (x=1189, y=901, w=144, h=144)
# ✅ richard-whitney_nancy.jpg - Face 4 → White (x=311, y=970, w=105, h=105)
# ✅ richard-whitney_nancy.jpg - Face 5 → White (x=900, y=1595, w=60, h=60)
# ✅ akseli-gallen-kallela_symposium-1894.jpg - Face 1 → White (x=1144, y=478, w=206, h=206)
# ✅ akseli-gallen-kallela_symposium-1894.jpg - Face 2 → White (x=1545, y=631, w=210, h=210)
# ✅ anita-malfatti_a-estudante-russa-1915.jpg - Face 1 → White (x=333, y=99, w=367, h=367)
# ✅ anita-malfatti_a-estudante-russa-1915.jpg - Face 2 → Black (x=9, y=950, w=110, h=110)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 1 → White (x=1556, y=260, w=111, h=111)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 2 → Latino_Hispanic (x=180, y=517, w=282, h=282)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 3 → Black (x=148, y=620, w=72, h=72)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 4 → Black (x=904, y=651, w=100, h=100)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 5 → White (x=647, y=664, w=111, h=111)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 6 → Latino_Hispanic (x=1022, y=792, w=56, h=56)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 7 → Black (x=202, y=813, w=71, h=71)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 8 → Other (x=990, y=832, w=87, h=87)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 9 → White (x=656, y=852, w=106, h=106)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 10 → White (x=660, y=896, w=97, h=97)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 11 → White (x=1635, y=973, w=53, h=53)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 12 → Black (x=981, y=920, w=90, h=90)
# ✅ jacob-jordaens_homage-to-pomona-1616.jpg - Face 1 → White (x=1297, y=545, w=49, h=49)
# ✅ jacob-jordaens_homage-to-pomona-1616.jpg - Face 2 → White (x=773, y=716, w=372, h=372)
# ✅ jacob-jordaens_homage-to-pomona-1616.jpg - Face 3 → Latino_Hispanic (x=56, y=953, w=69, h=69)
# ✅ jacob-jordaens_homage-to-pomona-1616.jpg - Face 4 → East Asian (x=1333, y=1147, w=49, h=49)
# ✅ richard-whitney_allen-kenney.jpg - Face 1 → White (x=383, y=382, w=596, h=596)
# ✅ aristarkh-lentulov_self-portrait-1915.jpg - Face 1 → White (x=569, y=38, w=307, h=307)
# ✅ basuki-abdullah_an-indonesian-beauty.jpg - Face 1 → Black (x=286, y=321, w=135, h=135)
# ✅ basuki-abdullah_an-indonesian-beauty.jpg - Face 2 → White (x=15, y=921, w=277, h=277)
# ✅ amrita-sher-gil_three-girls-1935.jpg - Face 1 → Senior (x=459, y=185, w=232, h=232)
# ✅ amrita-sher-gil_three-girls-1935.jpg - Face 2 → Senior (x=851, y=343, w=294, h=294)
# ✅ amrita-sher-gil_three-girls-1935.jpg - Face 3 → East Asian (x=47, y=541, w=263, h=263)
# ✅ john-french-sloan_young-woman-in-black-and-white-mary-kerr-1902.jpg - Face 1 → White (x=500, y=435, w=385, h=385)
# ✅ john-french-sloan_young-woman-in-black-and-white-mary-kerr-1902.jpg - Face 2 → Latino_Hispanic (x=151, y=1134, w=94, h=94)
# ⚠️ Aucun visage détecté dans boris-kustodiev_portrait-of-a-k-kashparova-1911.jpg
# ✅ basuki-abdullah_bocah.jpg - Face 1 → Latino_Hispanic (x=567, y=419, w=343, h=343)
# ✅ alexey-venetsianov_head-of-an-old-peasant.jpg - Face 1 → White (x=563, y=308, w=242, h=242)
# ✅ alexey-venetsianov_head-of-an-old-peasant.jpg - Face 2 → Black (x=650, y=643, w=94, h=94)
# ✅ alexey-venetsianov_head-of-an-old-peasant.jpg - Face 3 → Black (x=729, y=828, w=60, h=60)
# ✅ anton-azbe_zamorka-black-girl-1895.jpg - Face 1 → Black (x=354, y=523, w=568, h=568)
# ✅ ernst-ludwig-kirchner_reclining-female-nude.jpg - Face 1 → Senior (x=469, y=366, w=545, h=545)
# ✅ ernst-ludwig-kirchner_reclining-female-nude.jpg - Face 2 → White (x=1004, y=1094, w=173, h=173)
# ✅ ernst-ludwig-kirchner_reclining-female-nude.jpg - Face 3 → White (x=850, y=1987, w=234, h=234)
# ✅ alexey-venetsianov_girl-with-accordion.jpg - Face 1 → White (x=273, y=437, w=586, h=586)
# ✅ alexey-venetsianov_girl-with-accordion.jpg - Face 2 → White (x=1062, y=1110, w=50, h=50)
# ✅ alexey-venetsianov_girl-with-accordion.jpg - Face 3 → White (x=1092, y=1181, w=53, h=53)
# ✅ alexey-venetsianov_girl-with-accordion.jpg - Face 4 → White (x=1099, y=1198, w=60, h=60)
# ✅ alexey-venetsianov_girl-with-accordion.jpg - Face 5 → White (x=917, y=1504, w=47, h=47)
# ✅ jamie-wyeth_kalounna-in-frogtown-1986.jpg - Face 1 → Latino_Hispanic (x=813, y=157, w=247, h=247)
# ✅ augustus-john_mrs-a-a-jack-1898.jpg - Face 1 → White (x=405, y=349, w=506, h=506)
# ✅ augustus-john_mrs-a-a-jack-1898.jpg - Face 2 → White (x=973, y=1071, w=104, h=104)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_l-escale-1913.jpg - Face 1 → White (x=1314, y=945, w=55, h=55)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 1 → White (x=161, y=194, w=65, h=65)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 2 → White (x=1814, y=473, w=67, h=67)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 3 → Latino_Hispanic (x=674, y=481, w=64, h=64)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 4 → East Asian (x=880, y=480, w=722, h=722)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 5 → Latino_Hispanic (x=680, y=522, w=65, h=65)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 6 → White (x=1429, y=613, w=58, h=58)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 7 → Male (x=1374, y=748, w=63, h=63)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 8 → White (x=263, y=777, w=57, h=57)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 9 → White (x=1475, y=703, w=115, h=115)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 10 → White (x=595, y=953, w=60, h=60)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 11 → White (x=353, y=1173, w=64, h=64)
# ✅ camille-corot_algerian-woman.jpg - Face 1 → White (x=482, y=207, w=458, h=458)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 1 → Latino_Hispanic (x=1192, y=401, w=76, h=76)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 2 → Senior (x=955, y=235, w=119, h=119)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 3 → Latino_Hispanic (x=646, y=944, w=59, h=59)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 4 → Black (x=478, y=632, w=75, h=75)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 5 → Black (x=185, y=1134, w=60, h=60)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 6 → Latino_Hispanic (x=1019, y=1304, w=59, h=59)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 7 → White (x=919, y=1641, w=144, h=144)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 8 → White (x=1205, y=1691, w=116, h=116)
# ✅ augustus-john_edwin-john-1927.jpg - Face 1 → White (x=458, y=234, w=238, h=238)
# ✅ jamie-wyeth_portrait-of-andrew-wyeth-1969.jpg - Face 1 → Other (x=602, y=109, w=360, h=360)
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 1 → White (x=985, y=220, w=156, h=156)
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 2 → Black (x=1228, y=386, w=58, h=58)
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 3 → White (x=687, y=433, w=162, h=162)
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 4 → White (x=1604, y=451, w=153, h=153)
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 5 → Latino_Hispanic (x=667, y=953, w=54, h=54)
# ⚠️ Aucun visage détecté dans juan-gris_pierrot-with-guitar-1925.jpg
# ✅ martial-raysse_portrait-de-mme-raysse-1963.jpg - Face 1 → White (x=501, y=418, w=611, h=611)
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 1 → White (x=358, y=448, w=78, h=78)
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 2 → White (x=448, y=306, w=377, h=377)
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 3 → White (x=1209, y=862, w=77, h=77)
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 4 → Latino_Hispanic (x=325, y=998, w=93, h=93)
# 📊 Analyse terminée ! Résultats enregistrés dans face_identification_results.csv
#                                                  image face_id  \
# 0    sandro-botticelli_the-temptation-of-christ-148...  Face 1
# 1    sandro-botticelli_the-temptation-of-christ-148...  Face 2
# 2    sandro-botticelli_the-temptation-of-christ-148...  Face 3
# 3    sandro-botticelli_the-temptation-of-christ-148...  Face 4
# 4    sandro-botticelli_the-temptation-of-christ-148...  Face 5
# ..                                                 ...     ...
# 232     martial-raysse_portrait-de-mme-raysse-1963.jpg  Face 1
# 233         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 1
# 234         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 2
# 235         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 3
# 236         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 4
#
#            ethnicity       x       y      w      h
# 0              White   123.0   494.0   60.0   60.0
# 1              Black   847.0   756.0   69.0   69.0
# 2              Black  1477.0   766.0   73.0   73.0
# 3              White  1859.0   879.0  173.0  173.0
# 4              White  1244.0  1151.0   49.0   49.0
# ..               ...     ...     ...    ...    ...
# 232            White   501.0   418.0  611.0  611.0
# 233            White   358.0   448.0   78.0   78.0
# 234            White   448.0   306.0  377.0  377.0
# 235            White  1209.0   862.0   77.0   77.0
# 236  Latino_Hispanic   325.0   998.0   93.0   93.0
#
# [237 rows x 7 columns]

# %% [markdown]
# ## Limitation aux 6 premières cat

# %%
import torch
import os
import pandas as pd
import cv2
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image
import numpy as np
from IPython.display import display

# 📌 Définition des 6 catégories FairFace que l'on veut garder
ethnicities = [
    "White", "Black", "Latino_Hispanic", "East Asian", "Southeast Asian", 
    "Indian"
]

# 📌 Charger le modèle FairFace
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet34(pretrained=False)

# 📌 Ne PAS modifier la couche fc, on garde les 18 classes
model.fc = torch.nn.Linear(model.fc.in_features, 18)

# 📌 Chemin du fichier modèle (⚠️ Modifier ici si nécessaire)
model_path = "../FairFace/res34_fair_align_multi_4_20190809.pt"

if not os.path.exists(model_path):
    raise FileNotFoundError(f"⚠️ Le fichier modèle {model_path} est introuvable.")

# Charger les poids du modèle (pré-entraîné avec 18 classes)
model.load_state_dict(torch.load(model_path, map_location=device))
model.to(device)
model.eval()

print("✅ Modèle FairFace chargé avec succès avec 18 catégories, en filtrant sur 6 catégories.")

# 🔹 Transformation des images
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 🔹 Détecteur de visages OpenCV
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

def detect_faces(image_path):
    """ Détecte les visages et retourne une liste des coordonnées (x, y, w, h) """
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    return faces

def predict_ethnicity(face_image):
    """ Prédiction de l'ethnicité d'un visage (en filtrant sur 6 catégories) """
    try:
        face_pil = Image.fromarray(cv2.cvtColor(face_image, cv2.COLOR_BGR2RGB))
        face_pil = transform(face_pil).unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(face_pil)  # Sortie avec 18 classes
            output = output[:,:6]  # 📌 On garde seulement les 6 premières classes
            prediction = torch.argmax(output, dim=1).item()

        return ethnicities[prediction]  # Associer l'indice à l'ethnicité correspondante
    except Exception as e:
        print(f"⚠️ Erreur avec un visage : {e}")
        return "Unknown"

# 📌 Dossier des images (⚠️ Modifier ici)
image_folder = "../raw_data/painting_test_set"
output_folder = "../processed_data/FairFace"
os.makedirs(output_folder, exist_ok=True)

if not os.path.exists(image_folder):
    raise FileNotFoundError(f"⚠️ Le dossier {image_folder} est introuvable.")

# 🔹 Stocker les résultats
results = []

# 🔹 Traitement des images
for img_file in os.listdir(image_folder):
    img_path = os.path.join(image_folder, img_file)

    if img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
        image = cv2.imread(img_path)
        faces = detect_faces(img_path)
        
        if len(faces) == 0:
            print(f"⚠️ Aucun visage détecté dans {img_file}")
            results.append({"image": img_file, "face_id": "None", "ethnicity": "Unknown", "x": None, "y": None, "w": None, "h": None})
        else:
            for i, (x, y, w, h) in enumerate(faces):
                face = image[y:y+h, x:x+w]
                ethnicity = predict_ethnicity(face)

                results.append({"image": img_file, "face_id": f"Face {i+1}", "ethnicity": ethnicity, "x": x, "y": y, "w": w, "h": h})
                print(f"✅ {img_file} - Face {i+1} → {ethnicity} (x={x}, y={y}, w={w}, h={h})")

                # 🖼 Annoter l'image
                cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
                cv2.putText(image, ethnicity, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

            # Sauvegarder l'image annotée
            annotated_path = os.path.join(output_folder, f"annotated_{img_file}")
            cv2.imwrite(annotated_path, image)

# 🔹 Convertir en DataFrame et sauvegarder
df_results = pd.DataFrame(results)
df_results.to_csv("face_identification_results_6_classes.csv", index=False)

print("📊 Analyse terminée ! Résultats enregistrés dans face_identification_results_6_classes.csv")

# 🔹 Afficher les résultats dans Jupyter Notebook
display(df_results)
# Out:
# /home/carozero/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/carozero/.pyenv/versions/3.10.6/envs/delorean_art/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ✅ Modèle FairFace chargé avec succès avec 18 catégories, en filtrant sur 6 catégories.
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 1 → White (x=123, y=494, w=60, h=60)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 2 → Black (x=847, y=756, w=69, h=69)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 3 → Black (x=1477, y=766, w=73, h=73)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 4 → White (x=1859, y=879, w=173, h=173)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 5 → White (x=1244, y=1151, w=49, h=49)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 6 → White (x=1355, y=1119, w=165, h=165)
# ✅ sandro-botticelli_the-temptation-of-christ-1482(1).jpg - Face 7 → White (x=292, y=1299, w=60, h=60)
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 1 → Latino_Hispanic (x=1156, y=681, w=50, h=50)
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 2 → White (x=430, y=607, w=73, h=73)
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 3 → East Asian (x=760, y=951, w=72, h=72)
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 4 → Latino_Hispanic (x=807, y=1070, w=74, h=74)
# ✅ keisai-eisen_kiyomizu-komachi-1838.jpg - Face 5 → White (x=1177, y=1627, w=40, h=40)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 1 → White (x=593, y=239, w=188, h=188)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 2 → East Asian (x=1171, y=270, w=218, h=218)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 3 → Latino_Hispanic (x=1345, y=210, w=494, h=494)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 4 → Latino_Hispanic (x=649, y=624, w=61, h=61)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 5 → White (x=36, y=623, w=133, h=133)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 6 → Black (x=2296, y=675, w=102, h=102)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 7 → White (x=116, y=864, w=52, h=52)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 8 → White (x=127, y=916, w=59, h=59)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_le-judgment-de-paris-1927.jpg - Face 9 → White (x=1383, y=1041, w=106, h=106)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 1 → Black (x=860, y=125, w=59, h=59)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 2 → Black (x=1016, y=363, w=67, h=67)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 3 → Latino_Hispanic (x=867, y=315, w=153, h=153)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 4 → East Asian (x=1077, y=312, w=167, h=167)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 5 → White (x=588, y=346, w=156, h=156)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face 6 → Latino_Hispanic (x=214, y=443, w=227, h=227)
# ✅ benozzo-gozzoli_scenes-with-st-ambrose-detail-1465.jpg - Face
# ✅ amrita-sher-gil_bride-s-toilet-1937.jpg - Face 4 → Black (x=24, y=500, w=122, h=122)
# ✅ anders-zorn_mrs-walter-bacon-1891.jpg - Face 1 → White (x=344, y=354, w=409, h=409)
# ✅ anders-zorn_mrs-walter-bacon-1891.jpg - Face 2 → Latino_Hispanic (x=34, y=1365, w=67, h=67)
# ✅ anders-zorn_mrs-walter-bacon-1891.jpg - Face 3 → Latino_Hispanic (x=250, y=1170, w=80, h=80)
# ✅ anders-zorn_mrs-walter-bacon-1891.jpg - Face 4 → Latino_Hispanic (x=778, y=1299, w=102, h=102)
# ✅ anders-zorn_mrs-walter-bacon-1891.jpg - Face 5 → White (x=998, y=1591, w=47, h=47)
# ✅ basuki-abdullah_gadis-manis.jpg - Face 1 → Black (x=230, y=286, w=551, h=551)
# ✅ utagawa-kuniyoshi_portrait-of-daruma.jpg - Face 1 → White (x=902, y=1193, w=68, h=68)
# ⚠️ Aucun visage détecté dans kazimir-malevich_study-for-portrait-of-a-peasant.jpg
# ✅ theo-van-rysselberghe_three-children-in-blue-1901.jpg - Face 1 → East Asian (x=1362, y=208, w=37, h=37)
# ✅ theo-van-rysselberghe_three-children-in-blue-1901.jpg - Face 2 → White (x=1172, y=246, w=147, h=147)
# ✅ theo-van-rysselberghe_three-children-in-blue-1901.jpg - Face 3 → White (x=345, y=295, w=133, h=133)
# ✅ theo-van-rysselberghe_three-children-in-blue-1901.jpg - Face 4 → White (x=1016, y=311, w=149, h=149)
# ✅ theo-van-rysselberghe_three-children-in-blue-1901.jpg - Face 5 → East Asian (x=380, y=883, w=73, h=73)
# ✅ utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen.jpg - Face 1 → White (x=678, y=362, w=68, h=68)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 1 → East Asian (x=1271, y=316, w=55, h=55)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 2 → Black (x=76, y=400, w=64, h=64)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 3 → White (x=181, y=378, w=71, h=71)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 4 → White (x=869, y=413, w=164, h=164)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 5 → White (x=1019, y=527, w=57, h=57)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 6 → White (x=666, y=566, w=67, h=67)
# ✅ jacob-jordaens_king-drinks-1640.jpg - Face 7 → White (x=104, y=866, w=159, h=159)
# ✅ fernando-botero_pope-leo-x-after-raphael.jpg - Face 1 → White (x=362, y=446, w=491, h=491)
# ⚠️ Aucun visage détecté dans fernand-leger_head-constructor-1950.jpg
# ✅ albert-huie_the-counting-lesson-1938.jpg - Face 1 → East Asian (x=214, y=144, w=73, h=73)
# ✅ albert-huie_the-counting-lesson-1938.jpg - Face 2 → East Asian (x=568, y=361, w=483, h=483)
# ✅ albert-huie_the-counting-lesson-1938.jpg - Face 3 → White (x=804, y=1141, w=58, h=58)
# ✅ yayoi-kusama_watching-the-sea-1989.jpg - Face 1 → East Asian (x=274, y=101, w=59, h=59)
# ✅ yayoi-kusama_watching-the-sea-1989.jpg - Face 2 → East Asian (x=1191, y=81, w=58, h=58)
# ✅ yayoi-kusama_watching-the-sea-1989.jpg - Face 3 → Black (x=1149, y=124, w=57, h=57)
# ✅ yayoi-kusama_watching-the-sea-1989.jpg - Face 4 → East Asian (x=1078, y=755, w=60, h=60)
# ✅ augustus-john_the-two-jamaican-girls-1937.jpg - Face 1 → White (x=959, y=925, w=43, h=43)
# ✅ augustus-john_the-two-jamaican-girls-1937.jpg - Face 2 → White (x=182, y=799, w=93, h=93)
# ✅ augustus-john_the-two-jamaican-girls-1937.jpg - Face 3 → White (x=109, y=851, w=117, h=117)
# ✅ augustus-john_the-two-jamaican-girls-1937.jpg - Face 4 → White (x=1023, y=1262, w=62, h=62)
# ✅ augustus-john_the-two-jamaican-girls-1937.jpg - Face 5 → Black (x=763, y=1503, w=53, h=53)
# ✅ basuki-abdullah_cantik.jpg - Face 1 → East Asian (x=506, y=241, w=475, h=475)
# ✅ andy-warhol_sylvester-stallone-1980.jpg - Face 1 → East Asian (x=384, y=434, w=663, h=663)
# ✅ andy-warhol_sylvester-stallone-1980.jpg - Face 2 → Latino_Hispanic (x=590, y=519, w=67, h=67)
# ⚠️ Aucun visage détecté dans ernst-ludwig-kirchner_great-lovers-mr-and-miss-hembus.jpg
# ✅ keisai-eisen_pipe-smokers-1835(1).jpg - Face 1 → East Asian (x=223, y=384, w=68, h=68)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 1 → White (x=397, y=213, w=84, h=84)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 2 → White (x=346, y=345, w=187, h=187)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 3 → East Asian (x=1197, y=609, w=36, h=36)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 4 → Black (x=327, y=908, w=56, h=56)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 5 → White (x=772, y=1085, w=72, h=72)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 6 → Latino_Hispanic (x=751, y=1013, w=64, h=64)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 7 → Latino_Hispanic (x=1618, y=988, w=74, h=74)
# ✅ jacob-jordaens_rape-of-europa-1615.jpg - Face 8 → White (x=1358, y=1017, w=89, h=89)
# ✅ boris-kustodiev_portrait-of-a-n-protasova-1900.jpg - Face 1 → White (x=496, y=279, w=396, h=396)
# ✅ jacob-jordaens_study-of-the-head-of-apollo.jpg - Face 1 → White (x=381, y=197, w=444, h=444)
# ✅ jacob-jordaens_study-of-the-head-of-apollo.jpg - Face 2 → East Asian (x=867, y=583, w=114, h=114)
# ✅ eric-fischl_willie-and-liz.jpg - Face 1 → Black (x=1166, y=65, w=197, h=197)
# ✅ eric-fischl_willie-and-liz.jpg - Face 2 → Black (x=251, y=135, w=209, h=209)
# ✅ eric-fischl_willie-and-liz.jpg - Face 3 → Latino_Hispanic (x=1063, y=1199, w=83, h=83)
# ✅ gilles-aillaud_la-bataille-du-riz-1968.jpg - Face 1 → Latino_Hispanic (x=431, y=315, w=103, h=103)
# ✅ gilles-aillaud_la-bataille-du-riz-1968.jpg - Face 2 → Latino_Hispanic (x=710, y=816, w=70, h=70)
# ✅ martial-raysse_made-in-japan-la-grande-odalisque-1964.jpg - Face 1 → Latino_Hispanic (x=622, y=467, w=637, h=637)
# ✅ martial-raysse_made-in-japan-la-grande-odalisque-1964.jpg - Face 2 → Latino_Hispanic (x=298, y=530, w=259, h=259)
# ✅ alexey-venetsianov_girl-with-milk.jpg - Face 1 → White (x=186, y=462, w=617, h=617)
# ✅ alexey-venetsianov_girl-with-milk.jpg - Face 2 → White (x=359, y=1161, w=71, h=71)
# ✅ alexey-venetsianov_girl-with-milk.jpg - Face 3 → White (x=165, y=1094, w=127, h=127)
# ✅ alexey-venetsianov_girl-with-milk.jpg - Face 4 → White (x=538, y=1337, w=63, h=63)
# ✅ alexey-venetsianov_girl-with-milk.jpg - Face 5 → White (x=19, y=1521, w=81, h=81)
# ✅ antÔö£ð¦Ôö¼Ôöénio-de-carvalho-da-silva-porto
# ✅ edouard-vuillard_self-portrait.jpg - Face 3 → Black (x=975, y=1309, w=60, h=60)
# ✅ richard-whitney_nancy.jpg - Face 1 → White (x=725, y=349, w=259, h=259)
# ✅ richard-whitney_nancy.jpg - Face 2 → White (x=136, y=498, w=82, h=82)
# ✅ richard-whitney_nancy.jpg - Face 3 → White (x=1189, y=901, w=144, h=144)
# ✅ richard-whitney_nancy.jpg - Face 4 → White (x=311, y=970, w=105, h=105)
# ✅ richard-whitney_nancy.jpg - Face 5 → White (x=900, y=1595, w=60, h=60)
# ✅ akseli-gallen-kallela_symposium-1894.jpg - Face 1 → White (x=1144, y=478, w=206, h=206)
# ✅ akseli-gallen-kallela_symposium-1894.jpg - Face 2 → White (x=1545, y=631, w=210, h=210)
# ✅ anita-malfatti_a-estudante-russa-1915.jpg - Face 1 → White (x=333, y=99, w=367, h=367)
# ✅ anita-malfatti_a-estudante-russa-1915.jpg - Face 2 → Black (x=9, y=950, w=110, h=110)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 1 → White (x=1556, y=260, w=111, h=111)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 2 → Latino_Hispanic (x=180, y=517, w=282, h=282)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 3 → Black (x=148, y=620, w=72, h=72)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 4 → Black (x=904, y=651, w=100, h=100)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 5 → White (x=647, y=664, w=111, h=111)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 6 → Latino_Hispanic (x=1022, y=792, w=56, h=56)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 7 → Black (x=202, y=813, w=71, h=71)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 8 → White (x=990, y=832, w=87, h=87)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 9 → White (x=656, y=852, w=106, h=106)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 10 → White (x=660, y=896, w=97, h=97)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 11 → Black (x=981, y=920, w=90, h=90)
# ✅ ferdinand-hodler_youth-admired-by-women.jpg - Face 12 → White (x=1635, y=973, w=53, h=53)
# ✅ jacob-jordaens_homage-to-pomona-1616.jpg - Face 1 → White (x=1297, y=545, w=49, h=49)
# ✅ jacob-jordaens_homage-to-pomona-1616.jpg - Face 2 → White (x=773, y=716, w=372, h=372)
# ✅ jacob-jordaens_homage-to-pomona-1616.jpg - Face 3 → Latino_Hispanic (x=56, y=953, w=69, h=69)
# ✅ jacob-jordaens_homage-to-pomona-1616.jpg - Face 4 → East Asian (x=1333, y=1147, w=49, h=49)
# ✅ richard-whitney_allen-kenney.jpg - Face 1 → White (x=383, y=382, w=596, h=596)
# ✅ aristarkh-lentulov_self-portrait-1915.jpg - Face 1 → White (x=569, y=38, w=307, h=307)
# ✅ basuki-abdullah_an-indonesian-beauty.jpg - Face 1 → Black (x=286, y=321, w=135, h=135)
# ✅ basuki-abdullah_an-indonesian-beauty.jpg - Face 2 → White (x=15, y=921, w=277, h=277)
# ✅ amrita-sher-gil_three-girls-1935.jpg - Face 1 → Latino_Hispanic (x=459, y=185, w=232, h=232)
# ✅ amrita-sher-gil_three-girls-1935.jpg - Face 2 → East Asian (x=851, y=343, w=294, h=294)
# ✅ amrita-sher-gil_three-girls-1935.jpg - Face 3 → East Asian (x=47, y=541, w=263, h=263)
# ✅ john-french-sloan_young-woman-in-black-and-white-mary-kerr-1902.jpg - Face 1 → White (x=500, y=435, w=385, h=385)
# ✅ john-french-sloan_young-woman-in-black-and-white-mary-kerr-1902.jpg - Face 2 → Latino_Hispanic (x=151, y=1134, w=94, h=94)
# ⚠️ Aucun visage détecté dans boris-kustodiev_portrait-of-a-k-kashparova-1911.jpg
# ✅ basuki-abdullah_bocah.jpg - Face 1 → Latino_Hispanic (x=567, y=419, w=343, h=343)
# ✅ alexey-venetsianov_head-of-an-old-peasant.jpg - Face 1 → White (x=563, y=308, w=242, h=242)
# ✅ alexey-venetsianov_head-of-an-old-peasant.jpg - Face 2 → Black (x=729, y=828, w=60, h=60)
# ✅ alexey-venetsianov_head-of-an-old-peasant.jpg - Face 3 → Black (x=650, y=643, w=94, h=94)
# ✅ anton-azbe_zamorka-black-girl-1895.jpg - Face 1 → Black (x=354, y=523, w=568, h=568)
# ✅ ernst-ludwig-kirchner_reclining-female-nude.jpg - Face 1 → White (x=469, y=366, w=545, h=545)
# ✅ ernst-ludwig-kirchner_reclining-female-nude.jpg - Face 2 → White (x=1004, y=1094, w=173, h=173)
# ✅ ernst-ludwig-kirchner_reclining-female-nude.jpg - Face 3 → White (x=850, y=1987, w=234, h=234)
# ✅ alexey-venetsianov_girl-with-accordion.jpg - Face 1 → White (x=273, y=437, w=586, h=586)
# ✅ alexey-venetsianov_girl-with-accordion.jpg - Face 2 → White (x=1062, y=1110, w=50, h=50)
# ✅ alexey-venetsianov_girl-with-accordion.jpg - Face 3 → White (x=1092, y=1181, w=53, h=53)
# ✅ alexey-venetsianov_girl-with-accordion.jpg - Face 4 → White (x=917, y=1504, w=47, h=47)
# ✅ alexey-venetsianov_girl-with-accordion.jpg - Face 5 → White (x=1099, y=1198, w=60, h=60)
# ✅ jamie-wyeth_kalounna-in-frogtown-1986.jpg - Face 1 → Latino_Hispanic (x=813, y=157, w=247, h=247)
# ✅ augustus-john_mrs-a-a-jack-1898.jpg - Face 1 → White (x=405, y=349, w=506, h=506)
# ✅ augustus-john_mrs-a-a-jack-1898.jpg - Face 2 → White (x=973, y=1071, w=104, h=104)
# ✅ andrÔö£ð¦Ôö¼ð¦-lhote_l-escale-1913.jpg - Face 1 → White (x=1314, y=945, w=55, h=55)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 1 → White (x=161, y=194, w=65, h=65)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 2 → White (x=1814, y=473, w=67, h=67)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 3 → Latino_Hispanic (x=674, y=481, w=64, h=64)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 4 → White (x=1429, y=613, w=58, h=58)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 5 → Latino_Hispanic (x=680, y=522, w=65, h=65)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 6 → East Asian (x=880, y=480, w=722, h=722)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 7 → White (x=1374, y=748, w=63, h=63)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 8 → White (x=263, y=777, w=57, h=57)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 9 → White (x=1475, y=703, w=115, h=115)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 10 → White (x=595, y=953, w=60, h=60)
# ✅ jacob-jordaens_lapiths-and-the-centaurs.jpg - Face 11 → White (x=353, y=1173, w=64, h=64)
# ✅ camille-corot_algerian-woman.jpg - Face 1 → White (x=482, y=207, w=458, h=458)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 1 → Latino_Hispanic (x=1192, y=401, w=76, h=76)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 2 → Black (x=955, y=235, w=119, h=119)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 3 → Latino_Hispanic (x=646, y=944, w=59, h=59)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 4 → Black (x=478, y=632, w=75, h=75)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 5 → Black (x=185, y=1134, w=60, h=60)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 6 → Latino_Hispanic (x=1019, y=1304, w=59, h=59)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 7 → White (x=1205, y=1691, w=116, h=116)
# ✅ edouard-vuillard_portrait-of-a-woman-in-profile.jpg - Face 8 → White (x=919, y=1641, w=144, h=144)
# ✅ augustus-john_edwin-john-1927.jpg - Face 1 → White (x=458, y=234, w=238, h=238)
# ✅ jamie-wyeth_portrait-of-andrew-wyeth-1969.jpg - Face 1 → White (x=602, y=109, w=360, h=360)
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 1 → White (x=985, y=220, w=156, h=156)
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 2 → Black (x=1228, y=386, w=58, h=58)
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 3 → White (x=687, y=433, w=162, h=162)
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 4 → White (x=1604, y=451, w=153, h=153)
# ✅ jacob-jordaens_as-the-old-sang-so-the-young-pipe-1640.jpg - Face 5 → Latino_Hispanic (x=667, y=953, w=54, h=54)
# ⚠️ Aucun visage détecté dans juan-gris_pierrot-with-guitar-1925.jpg
# ✅ martial-raysse_portrait-de-mme-raysse-1963.jpg - Face 1 → White (x=501, y=418, w=611, h=611)
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 1 → White (x=358, y=448, w=78, h=78)
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 2 → White (x=448, y=306, w=377, h=377)
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 3 → White (x=1209, y=862, w=77, h=77)
# ✅ john-french-sloan_jeanne-dubinsky-1942.jpg - Face 4 → Latino_Hispanic (x=325, y=998, w=93, h=93)
# 📊 Analyse terminée ! Résultats enregistrés dans face_identification_results_6_classes.csv
#                                                  image face_id  \
# 0    sandro-botticelli_the-temptation-of-christ-148...  Face 1
# 1    sandro-botticelli_the-temptation-of-christ-148...  Face 2
# 2    sandro-botticelli_the-temptation-of-christ-148...  Face 3
# 3    sandro-botticelli_the-temptation-of-christ-148...  Face 4
# 4    sandro-botticelli_the-temptation-of-christ-148...  Face 5
# ..                                                 ...     ...
# 232     martial-raysse_portrait-de-mme-raysse-1963.jpg  Face 1
# 233         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 1
# 234         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 2
# 235         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 3
# 236         john-french-sloan_jeanne-dubinsky-1942.jpg  Face 4
#
#            ethnicity       x       y      w      h
# 0              White   123.0   494.0   60.0   60.0
# 1              Black   847.0   756.0   69.0   69.0
# 2              Black  1477.0   766.0   73.0   73.0
# 3              White  1859.0   879.0  173.0  173.0
# 4              White  1244.0  1151.0   49.0   49.0
# ..               ...     ...     ...    ...    ...
# 232            White   501.0   418.0  611.0  611.0
# 233            White   358.0   448.0   78.0   78.0
# 234            White   448.0   306.0  377.0  377.0
# 235            White  1209.0   862.0   77.0   77.0
# 236  Latino_Hispanic   325.0   998.0   93.0   93.0
#
# [237 rows x 7 columns]
